# %%
import pandas as pd
import yfinance as yf

# %%
dir(yf)
# Out:
# ['EquityQuery',
#  'FundQuery',
#  'Industry',
#  'Market',
#  'PREDEFINED_SCREENER_QUERIES',
#  'Search',
#  'Sector',
#  'Ticker',
#  'Tickers',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'cache',
#  'const',
#  'data',
#  'domain',
#  'download',
#  'enable_debug_mode',
#  'exceptions',
#  'multi',
#  'scrapers',
#  'screen',
#  'screener',
#  'search',
#  'set_tz_cache_location',
#  'shared',
#  'ticker',
#  'tickers',
#  'utils',
#  'version',
#  'warnings']

# %%
tdg = yf.Ticker("AMZN")
data = tdg.history()
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-02-28 00:00:00-05:00  208.649994  212.619995  206.990005  212.279999
# 2025-03-03 00:00:00-05:00  213.350006  214.009995  202.550003  205.020004
# 2025-03-04 00:00:00-05:00  200.110001  206.800003  197.429993  203.800003
# 2025-03-05 00:00:00-05:00  204.800003  209.979996  203.259995  208.360001
# 2025-03-06 00:00:00-05:00  204.399994  205.770004  198.300003  200.699997
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-02-28 00:00:00-05:00  51771700        0.0           0.0
# 2025-03-03 00:00:00-05:00  42948400        0.0           0.0
# 2025-03-04 00:00:00-05:00  60853100        0.0           0.0
# 2025-03-05 00:00:00-05:00  38610100        0.0           0.0
# 2025-03-06 00:00:00-05:00  49863800        0.0           0.0
